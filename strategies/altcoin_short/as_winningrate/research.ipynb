# %% [markdown]
# # Altcoin Short Strategy - Research Notebook
#
# ## 策略概述
#
# 做空市值排名 15-300 的 Altcoin，主要特点：
# - 排除 RWA、AI、Stablecoin
# - 基于波动率加权选币
# - 动态止盈止损
# - 熔断机制

# %%
# QuantBook for research
qb = QuantBook()

# Example: Add a crypto symbol
symbol = qb.add_crypto("BTCUSDT", Resolution.HOUR, Market.BINANCE).symbol

# Get historical data
history = qb.history(symbol, 168, Resolution.HOUR)
history.head()

# %%
import numpy as np
import pandas as pd

# Calculate volatility metrics
closes = history['close'].values
returns = np.diff(closes) / closes[:-1]

down_returns = returns[returns < 0]
up_returns = returns[returns > 0]

down_vol = abs(np.std(down_returns)) * np.sqrt(24) * 100
up_vol = abs(np.std(up_returns)) * np.sqrt(24) * 100

print(f"Downward Volatility: {down_vol:.2f}%")
print(f"Upward Volatility: {up_vol:.2f}%")
print(f"Downward Bias: {down_vol / (down_vol + up_vol):.3f}")

# %% [markdown]
# ## OBI (Order Book Imbalance) — LEAN vs Research
#
# **LEAN (alpha.py)** computes **depth OBI** from `CryptoFutureDepthData` (LOB L5):
# - **Bid depth** = sum of `depth` where `percentage < 0` (e.g. -5%, -4%, -3%, -2%, -1%)
# - **Ask depth** = sum of `depth` where `percentage > 0` (e.g. +1%, +2%, +3%, +4%, +5%)
# - **OBI** = `(bid_depth - ask_depth) / (bid_depth + ask_depth)` → in [-1, 1]
#
# **Research (checkpoint)** used **quote-based imbalance**: `(bid_size - ask_size) / (bid_size + ask_size + 1e-9)` from quote data — different data source (best bid/ask size only), so not directly comparable.
#
# To verify the framework calculates the factor correctly, research should compute OBI from **the same depth data** using the formula above. The cell below does that.

# %%
# OBI from depth data — same formula as LEAN (alpha.py)
# Requires depth data: data/custom/cryptofuture-depth/<symbol>/minute/<YYYYMMDD>_depth.zip (see DATA_LAYOUT.md)
# Same layout as CryptoFutureDepthData in utils.py (ms_midnight, percentage, depth, notional)

import sys
import os
import numpy as np
import pandas as pd
from datetime import datetime, timedelta, timezone

# Allow importing utils from strategy folder (run notebook from as_winningrate or project root)
for _d in [os.getcwd(), os.path.dirname(os.getcwd()), os.path.join(os.getcwd(), "strategies", "altcoin_short", "as_winningrate")]:
    if _d and _d not in sys.path:
        sys.path.insert(0, _d)

try:
    from utils import load_depth_data_range
    _has_utils = True
except Exception as e:
    _has_utils = False
    print("Utils not available (run from project or set path). Formula only:")
    print("  bid_depth = sum(depth for percentage < 0), ask_depth = sum(depth for percentage > 0)")
    print("  OBI = (bid_depth - ask_depth) / (bid_depth + ask_depth)")

def obi_from_depth_pivot(df_depth_pivot: pd.DataFrame) -> pd.Series:
    """Compute OBI from pivoted depth DataFrame. Matches LEAN alpha.py exactly.
    Columns are either numeric (percentage, e.g. -5, 5) or strings like 'depth_-5%'.
    """
    # load_depth_data_range(..., pivot=True) returns columns = percentage values (-5, -4, ..., 5)
    numeric_cols = [c for c in df_depth_pivot.columns if isinstance(c, (int, float))]
    str_cols = [c for c in df_depth_pivot.columns if isinstance(c, str) and c.startswith("depth_")]
    if numeric_cols:
        bid_cols = [c for c in numeric_cols if c < 0]
        ask_cols = [c for c in numeric_cols if c > 0]
    else:
        bid_cols = [c for c in str_cols if float(c.replace("depth_", "").replace("%", "")) < 0]
        ask_cols = [c for c in str_cols if float(c.replace("depth_", "").replace("%", "")) > 0]
    bid_depth = df_depth_pivot[bid_cols].sum(axis=1)
    ask_depth = df_depth_pivot[ask_cols].sum(axis=1)
    total = bid_depth + ask_depth
    obi = (bid_depth - ask_depth) / total.replace(0, np.nan)
    return obi

if _has_utils:
    # Load one day of depth for a symbol, aligned to minute (60000 ms) like LEAN
    symbol = "BTCUSDT"
    start = datetime(2026, 2, 3, tzinfo=timezone.utc)
    end = start + timedelta(days=1)
    df_depth = load_depth_data_range(symbol, start, end, pivot=True, align_ms=60000)
    if df_depth is not None and not df_depth.empty:
        if isinstance(df_depth.index, pd.MultiIndex):
            # (date, ms_midnight) index
            obi_series = obi_from_depth_pivot(df_depth)
            obi_series = obi_series.dropna()
        else:
            obi_series = obi_from_depth_pivot(df_depth).dropna()
        print("OBI from depth (LEAN formula) — sample (first 10 non-NaN):")
        print(obi_series.head(10))
        print("\nOBI stats:", obi_series.describe())
    else:
        print("No depth data found for", symbol, "on", start.date(), "- same as backtest log (No depth snapshot).")
        print("Add depth files to data/custom/cryptofuture-depth/<symbol>/minute/ to compare (see DATA_LAYOUT.md).")
else:
    # Demo with dummy snapshot matching LEAN structure
    dummy = pd.DataFrame({
        "depth_-5%": [100], "depth_-4%": [80], "depth_-3%": [70], "depth_-2%": [60], "depth_-1%": [50],
        "depth_1%": [40], "depth_2%": [50], "depth_3%": [60], "depth_4%": [70], "depth_5%": [80],
    })
    obi_val = obi_from_depth_pivot(dummy).iloc[0]
    print("Dummy snapshot: bid_depth=360, ask_depth=300 → OBI = (360-300)/(360+300) =", round(obi_val, 4))
